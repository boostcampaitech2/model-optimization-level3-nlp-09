# %%
# !pip install tensorly
# !pip install ptflops
# Out:
# Collecting tensorly
#   Downloading tensorly-0.7.0-py3-none-any.whl (198 kB)
#      |████████████████████████████████| 198 kB 5.7 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tensorly) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from tensorly) (1.4.1)
# Collecting nose
#   Downloading nose-1.3.7-py3-none-any.whl (154 kB)
#      |████████████████████████████████| 154 kB 27.3 MB/s
# Installing collected packages: nose, tensorly
# Successfully installed nose-1.3.7 tensorly-0.7.0
# Collecting ptflops
#   Downloading ptflops-0.6.6.tar.gz (11 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from ptflops) (1.9.0+cu111)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->ptflops) (3.10.0.2)
# Building wheels for collected packages: ptflops
#   Building wheel for ptflops (setup.py) ... done
#   Created wheel for ptflops: filename=ptflops-0.6.6-py3-none-any.whl size=8903 sha256=37eb9898a8d7d7c3d22b7f83e93f0fdf1323cd475ce99495eb2a053cb5cf65a4
#   Stored in directory: /root/.cache/pip/wheels/eb/7c/e5/2332373fcac1b39ba9eb95698ac370da3e14eaba5516e22721
# Successfully built ptflops
# Installing collected packages: ptflops
# Successfully installed ptflops-0.6.6

# %%
# helper function for training(fine-tuning)
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import models, datasets, transforms
from ptflops import get_model_complexity_info

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Pytorch transforms composition
transform = transforms.Compose(
    [
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ]
)
# Pytorch Datasets class
train_dataset = datasets.CIFAR10(
    "./data/cifar10", train=True, download=True, transform=transform
)
test_dataset = datasets.CIFAR10(
    "./data/cifar10", train=False, download=True, transform=transform
)
# Pytorch Dataloader class
TRAIN_DATALOADER = DataLoader(
    train_dataset, batch_size=64, shuffle=True, num_workers=2
)
TEST_DATALOADER = DataLoader(
    test_dataset, batch_size=64, shuffle=False, num_workers=2
)

@torch.no_grad()
def test(model):
  model.eval()
  correct, total = 0, 0
  for i, data in enumerate(TEST_DATALOADER):
    inputs, labels = data[0].to(DEVICE), data[1].to(DEVICE)
    outputs = model(inputs)
    _, preds = torch.max(outputs, 1)
    correct += (preds == labels).sum()
    total += labels.shape[0]
  print(f"Test acc: {correct/total*100.0:.2f}%")

def train(model, num_epochs=5):
  criterion = nn.CrossEntropyLoss()
  optimizer = optim.Adam(model.parameters())
  for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for i, data in enumerate(TRAIN_DATALOADER):
      inputs, labels = data[0].to(DEVICE), data[1].to(DEVICE)
      optimizer.zero_grad()
      outputs = model(inputs)
      
      loss = criterion(outputs, labels)
      loss.backward()
      optimizer.step()
      running_loss += loss.item()
    print('epoch : %d loss: %.3f' %(epoch + 1, running_loss / (i+1)))
    test(model)
  print('Finished Training')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## 1. 모델 및 데이터로더 생성, 학습

# %%
# Create model
class MyModel(nn.Module):
    def __init__(self, model_conv, label=10):
        super().__init__()
        self.features = model_conv.features
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(512, label)

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.fc(x)
        return x

def create_model():
  model_conv = models.vgg16_bn(pretrained=True)
  return MyModel(model_conv)

def get_macs(model):
  model = model.to(DEVICE)
  # calculate macs
  macs, params = get_model_complexity_info(model, tuple([3, 32, 32]), as_strings=True,
                                           print_per_layer_stat=True, verbose=True)
  return macs, params

# %%
# model creation test
test_model = create_model().to(DEVICE)
print(test_model)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16_bn-6c64b313.pth" to /opt/ml/.cache/torch/hub/checkpoints/vgg16_bn-6c64b313.pth
#   0%|          | 0.00/528M [00:00<?, ?B/s]
# MyModel(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace=True)
#     (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace=True)
#     (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (26): ReLU(inplace=True)
#     (27): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (28): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (32): ReLU(inplace=True)
#     (33): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (36): ReLU(inplace=True)
#     (37): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (38): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (39): ReLU(inplace=True)
#     (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (42): ReLU(inplace=True)
#     (43): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
def count_model_params(
    model: torch.nn.Module,
) -> int:
    """Count model's parameters"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

params_nums = count_model_params(test_model)
print(params_nums)
# Out:
# 4020358

# %% [markdown]
# ### Original 모델 MACs 확인

# %%
macs, params = get_macs(test_model)
print(f'original_model: {macs}')
# Out:
# Warning: module SiLU is treated as a zero-op.
# Warning: module ConvNormActivation is treated as a zero-op.
# Warning: module Sigmoid is treated as a zero-op.
# Warning: module SqueezeExcitation is treated as a zero-op.
# Warning: module StochasticDepth is treated as a zero-op.
# Warning: module MBConv is treated as a zero-op.
# Warning: module MyModel is treated as a zero-op.
# MyModel(
#   4.02 M, 100.000% Params, 0.009 GMac, 100.000% MACs,
#   (features): Sequential(
#     4.008 M, 99.681% Params, 0.009 GMac, 99.840% MACs,
#     (0): ConvNormActivation(
#       0.001 M, 0.023% Params, 0.0 GMac, 2.697% MACs,
#       (0): Conv2d(0.001 M, 0.021% Params, 0.0 GMac, 2.511% MACs, 3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(0.0 M, 0.002% Params, 0.0 GMac, 0.186% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#     )
#     (1): Sequential(
#       0.001 M, 0.036% Params, 0.0 GMac, 2.704% MACs,
#       (0): MBConv(
#         0.001 M, 0.036% Params, 0.0 GMac, 2.704% MACs,
#         (block): Sequential(
#           0.001 M, 0.036% Params, 0.0 GMac, 2.704% MACs,
#           (0): ConvNormActivation(
#             0.0 M, 0.009% Params, 0.0 GMac, 1.023% MACs,
#             (0): Conv2d(0.0 M, 0.007% Params, 0.0 GMac, 0.837% MACs, 32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(0.0 M, 0.002% Params, 0.0 GMac, 0.186% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): SqueezeExcitation(
#             0.001 M, 0.014% Params, 0.0 GMac, 0.099% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.093% MACs, output_size=1)
#             (fc1): Conv2d(0.0 M, 0.007% Params, 0.0 GMac, 0.003% MACs, 32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.0 M, 0.007% Params, 0.0 GMac, 0.003% MACs, 8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (2): ConvNormActivation(
#             0.001 M, 0.014% Params, 0.0 GMac, 1.581% MACs,
#             (0): Conv2d(0.001 M, 0.013% Params, 0.0 GMac, 1.488% MACs, 32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.001% Params, 0.0 GMac, 0.093% MACs, 16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#     )
#     (2): Sequential(
#       0.017 M, 0.416% Params, 0.001 GMac, 14.122% MACs,
#       (0): MBConv(
#         0.006 M, 0.149% Params, 0.001 GMac, 7.579% MACs,
#         (block): Sequential(
#           0.006 M, 0.149% Params, 0.001 GMac, 7.579% MACs,
#           (0): ConvNormActivation(
#             0.002 M, 0.043% Params, 0.0 GMac, 5.023% MACs,
#             (0): Conv2d(0.002 M, 0.038% Params, 0.0 GMac, 4.465% MACs, 16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.005% Params, 0.0 GMac, 0.558% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): ConvNormActivation(
#             0.001 M, 0.026% Params, 0.0 GMac, 0.767% MACs,
#             (0): Conv2d(0.001 M, 0.021% Params, 0.0 GMac, 0.628% MACs, 96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (1): BatchNorm2d(0.0 M, 0.005% Params, 0.0 GMac, 0.140% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             0.001 M, 0.022% Params, 0.0 GMac, 0.080% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.070% MACs, output_size=1)
#             (fc1): Conv2d(0.0 M, 0.010% Params, 0.0 GMac, 0.004% MACs, 96, 4, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.0 M, 0.012% Params, 0.0 GMac, 0.005% MACs, 4, 96, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (3): ConvNormActivation(
#             0.002 M, 0.059% Params, 0.0 GMac, 1.709% MACs,
#             (0): Conv2d(0.002 M, 0.057% Params, 0.0 GMac, 1.674% MACs, 96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.001% Params, 0.0 GMac, 0.035% MACs, 24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0125, mode=row)
#       )
#       (1): MBConv(
#         0.011 M, 0.266% Params, 0.001 GMac, 6.544% MACs,
#         (block): Sequential(
#           0.011 M, 0.266% Params, 0.001 GMac, 6.544% MACs,
#           (0): ConvNormActivation(
#             0.004 M, 0.093% Params, 0.0 GMac, 2.721% MACs,
#             (0): Conv2d(0.003 M, 0.086% Params, 0.0 GMac, 2.511% MACs, 24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.007% Params, 0.0 GMac, 0.209% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): ConvNormActivation(
#             0.002 M, 0.039% Params, 0.0 GMac, 1.151% MACs,
#             (0): Conv2d(0.001 M, 0.032% Params, 0.0 GMac, 0.942% MACs, 144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(0.0 M, 0.007% Params, 0.0 GMac, 0.209% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             0.002 M, 0.047% Params, 0.0 GMac, 0.126% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.105% MACs, output_size=1)
#             (fc1): Conv2d(0.001 M, 0.022% Params, 0.0 GMac, 0.010% MACs, 144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.001 M, 0.025% Params, 0.0 GMac, 0.011% MACs, 6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (3): ConvNormActivation(
#             0.004 M, 0.087% Params, 0.0 GMac, 2.546% MACs,
#             (0): Conv2d(0.003 M, 0.086% Params, 0.0 GMac, 2.511% MACs, 144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.001% Params, 0.0 GMac, 0.035% MACs, 24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.025, mode=row)
#       )
#     )
#     (3): Sequential(
#       0.047 M, 1.160% Params, 0.001 GMac, 9.403% MACs,
#       (0): MBConv(
#         0.015 M, 0.382% Params, 0.0 GMac, 4.535% MACs,
#         (block): Sequential(
#           0.015 M, 0.382% Params, 0.0 GMac, 4.535% MACs,
#           (0): ConvNormActivation(
#             0.004 M, 0.093% Params, 0.0 GMac, 2.721% MACs,
#             (0): Conv2d(0.003 M, 0.086% Params, 0.0 GMac, 2.511% MACs, 24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.007% Params, 0.0 GMac, 0.209% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): ConvNormActivation(
#             0.004 M, 0.097% Params, 0.0 GMac, 0.706% MACs,
#             (0): Conv2d(0.004 M, 0.090% Params, 0.0 GMac, 0.654% MACs, 144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#             (1): BatchNorm2d(0.0 M, 0.007% Params, 0.0 GMac, 0.052% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             0.002 M, 0.047% Params, 0.0 GMac, 0.047% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.026% MACs, output_size=1)
#             (fc1): Conv2d(0.001 M, 0.022% Params, 0.0 GMac, 0.010% MACs, 144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.001 M, 0.025% Params, 0.0 GMac, 0.011% MACs, 6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (3): ConvNormActivation(
#             0.006 M, 0.145% Params, 0.0 GMac, 1.061% MACs,
#             (0): Conv2d(0.006 M, 0.143% Params, 0.0 GMac, 1.046% MACs, 144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.002% Params, 0.0 GMac, 0.015% MACs, 40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.037500000000000006, mode=row)
#       )
#       (1): MBConv(
#         0.031 M, 0.778% Params, 0.0 GMac, 4.868% MACs,
#         (block): Sequential(
#           0.031 M, 0.778% Params, 0.0 GMac, 4.868% MACs,
#           (0): ConvNormActivation(
#             0.01 M, 0.251% Params, 0.0 GMac, 1.831% MACs,
#             (0): Conv2d(0.01 M, 0.239% Params, 0.0 GMac, 1.744% MACs, 40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.012% Params, 0.0 GMac, 0.087% MACs, 240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): ConvNormActivation(
#             0.006 M, 0.161% Params, 0.0 GMac, 1.177% MACs,
#             (0): Conv2d(0.006 M, 0.149% Params, 0.0 GMac, 1.090% MACs, 240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#             (1): BatchNorm2d(0.0 M, 0.012% Params, 0.0 GMac, 0.087% MACs, 240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             0.005 M, 0.126% Params, 0.0 GMac, 0.101% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.044% MACs, output_size=1)
#             (fc1): Conv2d(0.002 M, 0.060% Params, 0.0 GMac, 0.027% MACs, 240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.003 M, 0.066% Params, 0.0 GMac, 0.030% MACs, 10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (3): ConvNormActivation(
#             0.01 M, 0.241% Params, 0.0 GMac, 1.758% MACs,
#             (0): Conv2d(0.01 M, 0.239% Params, 0.0 GMac, 1.744% MACs, 240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.002% Params, 0.0 GMac, 0.015% MACs, 40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05, mode=row)
#       )
#     )
#     (4): Sequential(
#       0.243 M, 6.042% Params, 0.001 GMac, 10.947% MACs,
#       (0): MBConv(
#         0.037 M, 0.924% Params, 0.0 GMac, 2.899% MACs,
#         (block): Sequential(
#           0.037 M, 0.924% Params, 0.0 GMac, 2.899% MACs,
#           (0): ConvNormActivation(
#             0.01 M, 0.251% Params, 0.0 GMac, 1.831% MACs,
#             (0): Conv2d(0.01 M, 0.239% Params, 0.0 GMac, 1.744% MACs, 40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.012% Params, 0.0 GMac, 0.087% MACs, 240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): ConvNormActivation(
#             0.003 M, 0.066% Params, 0.0 GMac, 0.120% MACs,
#             (0): Conv2d(0.002 M, 0.054% Params, 0.0 GMac, 0.098% MACs, 240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#             (1): BatchNorm2d(0.0 M, 0.012% Params, 0.0 GMac, 0.022% MACs, 240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             0.005 M, 0.126% Params, 0.0 GMac, 0.068% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.011% MACs, output_size=1)
#             (fc1): Conv2d(0.002 M, 0.060% Params, 0.0 GMac, 0.027% MACs, 240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.003 M, 0.066% Params, 0.0 GMac, 0.030% MACs, 10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (3): ConvNormActivation(
#             0.019 M, 0.482% Params, 0.0 GMac, 0.879% MACs,
#             (0): Conv2d(0.019 M, 0.478% Params, 0.0 GMac, 0.872% MACs, 240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.004% Params, 0.0 GMac, 0.007% MACs, 80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0625, mode=row)
#       )
#       (1): MBConv(
#         0.103 M, 2.559% Params, 0.0 GMac, 4.024% MACs,
#         (block): Sequential(
#           0.103 M, 2.559% Params, 0.0 GMac, 4.024% MACs,
#           (0): ConvNormActivation(
#             0.039 M, 0.979% Params, 0.0 GMac, 1.788% MACs,
#             (0): Conv2d(0.038 M, 0.955% Params, 0.0 GMac, 1.744% MACs, 80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.001 M, 0.024% Params, 0.0 GMac, 0.044% MACs, 480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): ConvNormActivation(
#             0.005 M, 0.131% Params, 0.0 GMac, 0.240% MACs,
#             (0): Conv2d(0.004 M, 0.107% Params, 0.0 GMac, 0.196% MACs, 480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(0.001 M, 0.024% Params, 0.0 GMac, 0.044% MACs, 480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             0.02 M, 0.490% Params, 0.0 GMac, 0.245% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.022% MACs, output_size=1)
#             (fc1): Conv2d(0.01 M, 0.239% Params, 0.0 GMac, 0.109% MACs, 480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.01 M, 0.251% Params, 0.0 GMac, 0.114% MACs, 20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (3): ConvNormActivation(
#             0.039 M, 0.959% Params, 0.0 GMac, 1.751% MACs,
#             (0): Conv2d(0.038 M, 0.955% Params, 0.0 GMac, 1.744% MACs, 480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.004% Params, 0.0 GMac, 0.007% MACs, 80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.07500000000000001, mode=row)
#       )
#       (2): MBConv(
#         0.103 M, 2.559% Params, 0.0 GMac, 4.024% MACs,
#         (block): Sequential(
#           0.103 M, 2.559% Params, 0.0 GMac, 4.024% MACs,
#           (0): ConvNormActivation(
#             0.039 M, 0.979% Params, 0.0 GMac, 1.788% MACs,
#             (0): Conv2d(0.038 M, 0.955% Params, 0.0 GMac, 1.744% MACs, 80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.001 M, 0.024% Params, 0.0 GMac, 0.044% MACs, 480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): ConvNormActivation(
#             0.005 M, 0.131% Params, 0.0 GMac, 0.240% MACs,
#             (0): Conv2d(0.004 M, 0.107% Params, 0.0 GMac, 0.196% MACs, 480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(0.001 M, 0.024% Params, 0.0 GMac, 0.044% MACs, 480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             0.02 M, 0.490% Params, 0.0 GMac, 0.245% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.022% MACs, output_size=1)
#             (fc1): Conv2d(0.01 M, 0.239% Params, 0.0 GMac, 0.109% MACs, 480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.01 M, 0.251% Params, 0.0 GMac, 0.114% MACs, 20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (3): ConvNormActivation(
#             0.039 M, 0.959% Params, 0.0 GMac, 1.751% MACs,
#             (0): Conv2d(0.038 M, 0.955% Params, 0.0 GMac, 1.744% MACs, 480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.004% Params, 0.0 GMac, 0.007% MACs, 80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08750000000000001, mode=row)
#       )
#     )
#     (5): Sequential(
#       0.543 M, 13.510% Params, 0.002 GMac, 21.468% MACs,
#       (0): MBConv(
#         0.126 M, 3.134% Params, 0.0 GMac, 5.073% MACs,
#         (block): Sequential(
#           0.126 M, 3.134% Params, 0.0 GMac, 5.073% MACs,
#           (0): ConvNormActivation(
#             0.039 M, 0.979% Params, 0.0 GMac, 1.788% MACs,
#             (0): Conv2d(0.038 M, 0.955% Params, 0.0 GMac, 1.744% MACs, 80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.001 M, 0.024% Params, 0.0 GMac, 0.044% MACs, 480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): ConvNormActivation(
#             0.013 M, 0.322% Params, 0.0 GMac, 0.589% MACs,
#             (0): Conv2d(0.012 M, 0.298% Params, 0.0 GMac, 0.545% MACs, 480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#             (1): BatchNorm2d(0.001 M, 0.024% Params, 0.0 GMac, 0.044% MACs, 480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             0.02 M, 0.490% Params, 0.0 GMac, 0.245% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.022% MACs, output_size=1)
#             (fc1): Conv2d(0.01 M, 0.239% Params, 0.0 GMac, 0.109% MACs, 480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.01 M, 0.251% Params, 0.0 GMac, 0.114% MACs, 20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (3): ConvNormActivation(
#             0.054 M, 1.343% Params, 0.0 GMac, 2.452% MACs,
#             (0): Conv2d(0.054 M, 1.337% Params, 0.0 GMac, 2.442% MACs, 480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.006% Params, 0.0 GMac, 0.010% MACs, 112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#       )
#       (1): MBConv(
#         0.209 M, 5.188% Params, 0.001 GMac, 8.197% MACs,
#         (block): Sequential(
#           0.209 M, 5.188% Params, 0.001 GMac, 8.197% MACs,
#           (0): ConvNormActivation(
#             0.077 M, 1.906% Params, 0.0 GMac, 3.479% MACs,
#             (0): Conv2d(0.075 M, 1.872% Params, 0.0 GMac, 3.418% MACs, 112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.001 M, 0.033% Params, 0.0 GMac, 0.061% MACs, 672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): ConvNormActivation(
#             0.018 M, 0.451% Params, 0.0 GMac, 0.824% MACs,
#             (0): Conv2d(0.017 M, 0.418% Params, 0.0 GMac, 0.763% MACs, 672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(0.001 M, 0.033% Params, 0.0 GMac, 0.061% MACs, 672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             0.038 M, 0.953% Params, 0.0 GMac, 0.466% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.031% MACs, output_size=1)
#             (fc1): Conv2d(0.019 M, 0.469% Params, 0.0 GMac, 0.214% MACs, 672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.019 M, 0.485% Params, 0.0 GMac, 0.221% MACs, 28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (3): ConvNormActivation(
#             0.075 M, 1.878% Params, 0.0 GMac, 3.428% MACs,
#             (0): Conv2d(0.075 M, 1.872% Params, 0.0 GMac, 3.418% MACs, 672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.006% Params, 0.0 GMac, 0.010% MACs, 112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1125, mode=row)
#       )
#       (2): MBConv(
#         0.209 M, 5.188% Params, 0.001 GMac, 8.197% MACs,
#         (block): Sequential(
#           0.209 M, 5.188% Params, 0.001 GMac, 8.197% MACs,
#           (0): ConvNormActivation(
#             0.077 M, 1.906% Params, 0.0 GMac, 3.479% MACs,
#             (0): Conv2d(0.075 M, 1.872% Params, 0.0 GMac, 3.418% MACs, 112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.001 M, 0.033% Params, 0.0 GMac, 0.061% MACs, 672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): ConvNormActivation(
#             0.018 M, 0.451% Params, 0.0 GMac, 0.824% MACs,
#             (0): Conv2d(0.017 M, 0.418% Params, 0.0 GMac, 0.763% MACs, 672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(0.001 M, 0.033% Params, 0.0 GMac, 0.061% MACs, 672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             0.038 M, 0.953% Params, 0.0 GMac, 0.466% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.031% MACs, output_size=1)
#             (fc1): Conv2d(0.019 M, 0.469% Params, 0.0 GMac, 0.214% MACs, 672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.019 M, 0.485% Params, 0.0 GMac, 0.221% MACs, 28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (3): ConvNormActivation(
#             0.075 M, 1.878% Params, 0.0 GMac, 3.428% MACs,
#             (0): Conv2d(0.075 M, 1.872% Params, 0.0 GMac, 3.418% MACs, 672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.006% Params, 0.0 GMac, 0.010% MACs, 112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.125, mode=row)
#       )
#     )
#     (6): Sequential(
#       2.026 M, 50.402% Params, 0.002 GMac, 25.663% MACs,
#       (0): MBConv(
#         0.262 M, 6.529% Params, 0.0 GMac, 5.597% MACs,
#         (block): Sequential(
#           0.262 M, 6.529% Params, 0.0 GMac, 5.597% MACs,
#           (0): ConvNormActivation(
#             0.077 M, 1.906% Params, 0.0 GMac, 3.479% MACs,
#             (0): Conv2d(0.075 M, 1.872% Params, 0.0 GMac, 3.418% MACs, 112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.001 M, 0.033% Params, 0.0 GMac, 0.061% MACs, 672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): ConvNormActivation(
#             0.018 M, 0.451% Params, 0.0 GMac, 0.206% MACs,
#             (0): Conv2d(0.017 M, 0.418% Params, 0.0 GMac, 0.191% MACs, 672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(0.001 M, 0.033% Params, 0.0 GMac, 0.015% MACs, 672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             0.038 M, 0.953% Params, 0.0 GMac, 0.443% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.008% MACs, output_size=1)
#             (fc1): Conv2d(0.019 M, 0.469% Params, 0.0 GMac, 0.214% MACs, 672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.019 M, 0.485% Params, 0.0 GMac, 0.221% MACs, 28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (3): ConvNormActivation(
#             0.129 M, 3.219% Params, 0.0 GMac, 1.469% MACs,
#             (0): Conv2d(0.129 M, 3.209% Params, 0.0 GMac, 1.465% MACs, 672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.010% Params, 0.0 GMac, 0.004% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1375, mode=row)
#       )
#       (1): MBConv(
#         0.588 M, 14.624% Params, 0.001 GMac, 6.689% MACs,
#         (block): Sequential(
#           0.588 M, 14.624% Params, 0.001 GMac, 6.689% MACs,
#           (0): ConvNormActivation(
#             0.223 M, 5.559% Params, 0.0 GMac, 2.537% MACs,
#             (0): Conv2d(0.221 M, 5.502% Params, 0.0 GMac, 2.511% MACs, 192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.002 M, 0.057% Params, 0.0 GMac, 0.026% MACs, 1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): ConvNormActivation(
#             0.031 M, 0.774% Params, 0.0 GMac, 0.353% MACs,
#             (0): Conv2d(0.029 M, 0.716% Params, 0.0 GMac, 0.327% MACs, 1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(0.002 M, 0.057% Params, 0.0 GMac, 0.026% MACs, 1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             0.112 M, 2.781% Params, 0.0 GMac, 1.282% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.013% MACs, output_size=1)
#             (fc1): Conv2d(0.055 M, 1.377% Params, 0.0 GMac, 0.628% MACs, 1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.056 M, 1.404% Params, 0.0 GMac, 0.641% MACs, 48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (3): ConvNormActivation(
#             0.222 M, 5.511% Params, 0.0 GMac, 2.516% MACs,
#             (0): Conv2d(0.221 M, 5.502% Params, 0.0 GMac, 2.511% MACs, 1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.010% Params, 0.0 GMac, 0.004% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.15000000000000002, mode=row)
#       )
#       (2): MBConv(
#         0.588 M, 14.624% Params, 0.001 GMac, 6.689% MACs,
#         (block): Sequential(
#           0.588 M, 14.624% Params, 0.001 GMac, 6.689% MACs,
#           (0): ConvNormActivation(
#             0.223 M, 5.559% Params, 0.0 GMac, 2.537% MACs,
#             (0): Conv2d(0.221 M, 5.502% Params, 0.0 GMac, 2.511% MACs, 192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.002 M, 0.057% Params, 0.0 GMac, 0.026% MACs, 1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): ConvNormActivation(
#             0.031 M, 0.774% Params, 0.0 GMac, 0.353% MACs,
#             (0): Conv2d(0.029 M, 0.716% Params, 0.0 GMac, 0.327% MACs, 1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(0.002 M, 0.057% Params, 0.0 GMac, 0.026% MACs, 1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             0.112 M, 2.781% Params, 0.0 GMac, 1.282% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.013% MACs, output_size=1)
#             (fc1): Conv2d(0.055 M, 1.377% Params, 0.0 GMac, 0.628% MACs, 1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.056 M, 1.404% Params, 0.0 GMac, 0.641% MACs, 48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (3): ConvNormActivation(
#             0.222 M, 5.511% Params, 0.0 GMac, 2.516% MACs,
#             (0): Conv2d(0.221 M, 5.502% Params, 0.0 GMac, 2.511% MACs, 1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.010% Params, 0.0 GMac, 0.004% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1625, mode=row)
#       )
#       (3): MBConv(
#         0.588 M, 14.624% Params, 0.001 GMac, 6.689% MACs,
#         (block): Sequential(
#           0.588 M, 14.624% Params, 0.001 GMac, 6.689% MACs,
#           (0): ConvNormActivation(
#             0.223 M, 5.559% Params, 0.0 GMac, 2.537% MACs,
#             (0): Conv2d(0.221 M, 5.502% Params, 0.0 GMac, 2.511% MACs, 192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.002 M, 0.057% Params, 0.0 GMac, 0.026% MACs, 1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): ConvNormActivation(
#             0.031 M, 0.774% Params, 0.0 GMac, 0.353% MACs,
#             (0): Conv2d(0.029 M, 0.716% Params, 0.0 GMac, 0.327% MACs, 1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(0.002 M, 0.057% Params, 0.0 GMac, 0.026% MACs, 1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             0.112 M, 2.781% Params, 0.0 GMac, 1.282% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.013% MACs, output_size=1)
#             (fc1): Conv2d(0.055 M, 1.377% Params, 0.0 GMac, 0.628% MACs, 1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.056 M, 1.404% Params, 0.0 GMac, 0.641% MACs, 48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (3): ConvNormActivation(
#             0.222 M, 5.511% Params, 0.0 GMac, 2.516% MACs,
#             (0): Conv2d(0.221 M, 5.502% Params, 0.0 GMac, 2.511% MACs, 1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.010% Params, 0.0 GMac, 0.004% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17500000000000002, mode=row)
#       )
#     )
#     (7): Sequential(
#       0.717 M, 17.840% Params, 0.001 GMac, 8.156% MACs,
#       (0): MBConv(
#         0.717 M, 17.840% Params, 0.001 GMac, 8.156% MACs,
#         (block): Sequential(
#           0.717 M, 17.840% Params, 0.001 GMac, 8.156% MACs,
#           (0): ConvNormActivation(
#             0.223 M, 5.559% Params, 0.0 GMac, 2.537% MACs,
#             (0): Conv2d(0.221 M, 5.502% Params, 0.0 GMac, 2.511% MACs, 192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.002 M, 0.057% Params, 0.0 GMac, 0.026% MACs, 1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): ConvNormActivation(
#             0.013 M, 0.315% Params, 0.0 GMac, 0.144% MACs,
#             (0): Conv2d(0.01 M, 0.258% Params, 0.0 GMac, 0.118% MACs, 1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#             (1): BatchNorm2d(0.002 M, 0.057% Params, 0.0 GMac, 0.026% MACs, 1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             0.112 M, 2.781% Params, 0.0 GMac, 1.282% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.013% MACs, output_size=1)
#             (fc1): Conv2d(0.055 M, 1.377% Params, 0.0 GMac, 0.628% MACs, 1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.056 M, 1.404% Params, 0.0 GMac, 0.641% MACs, 48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (3): ConvNormActivation(
#             0.369 M, 9.185% Params, 0.0 GMac, 4.193% MACs,
#             (0): Conv2d(0.369 M, 9.169% Params, 0.0 GMac, 4.185% MACs, 1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.001 M, 0.016% Params, 0.0 GMac, 0.007% MACs, 320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1875, mode=row)
#       )
#     )
#     (8): ConvNormActivation(
#       0.412 M, 10.252% Params, 0.0 GMac, 4.680% MACs,
#       (0): Conv2d(0.41 M, 10.188% Params, 0.0 GMac, 4.651% MACs, 320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(0.003 M, 0.064% Params, 0.0 GMac, 0.029% MACs, 1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.015% MACs, output_size=(1, 1))
#   (fc): Linear(0.013 M, 0.319% Params, 0.0 GMac, 0.145% MACs, in_features=1280, out_features=10, bias=True)
# )
# original_model: 0.01 GMac

# %% [markdown]
# ### Fine tune 및 Original 모델 Acc 확인

# %%
print('Fine tune orignal model')
train(test_model, num_epochs = 10)
# Out:
# Fine tune orignal model
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-99a26f40818f> in <module>
#       1 print('Fine tune orignal model')
# ----> 2 train(test_model, num_epochs = 10)
#
# <ipython-input-1-4a5f902c1a9e> in train(model, num_epochs)
#      52       inputs, labels = data[0].to(DEVICE), data[1].to(DEVICE)
#      53       optimizer.zero_grad()
# ---> 54       outputs = model(inputs)
#      55
#      56       loss = criterion(outputs, labels)
#
# /opt/conda/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-8-4ae1d301fc6e> in forward(self, x)
#       8
#       9     def forward(self, x):
# ---> 10         x = self.features(x)
#      11         x = self.avgpool(x)
#      12         x = torch.flatten(x, 1)
#
# /opt/conda/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /opt/conda/lib/python3.8/site-packages/torch/nn/modules/container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# /opt/conda/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /opt/conda/lib/python3.8/site-packages/torch/nn/modules/container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# /opt/conda/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1095
#    1096     def _call_impl(self, *input, **kwargs):
# -> 1097         forward_call = (self._slow_forward if torch._C._get_tracing_state() else self.forward)
#    1098         # If we don't have any hooks, we want to skip the rest of the logic in
#    1099         # this function, and just call forward.
#
# KeyboardInterrupt:

# %% [markdown]
# ## 2. Conv에 rank parameter 추가(register_buffer)

# %%
for name, param in test_model.named_modules():
    if isinstance(param, nn.Conv2d):
        param.register_buffer('rank', torch.Tensor([0.5, 0.5])) # rank in, out

# %% [markdown]
# ## 3. Decomposition 수행

# %% [markdown]
# ### 3-1. Tucker decomposition 함수

# %%
import copy
import tensorly as tl
from tensorly.decomposition import parafac, partial_tucker
from typing import List
# switch to the PyTorch backend
tl.set_backend('pytorch')

def tucker_decomposition_conv_layer(
      layer: nn.Module,
      normed_rank: List[int] = [0.5, 0.5],
  ) -> nn.Module:
      """Gets a conv layer,
      returns a nn.Sequential object with the Tucker decomposition.
      The ranks are estimated with a Python implementation of VBMF
      https://github.com/CasvandenBogaard/VBMF
      """
      if hasattr(layer, "rank"):
          normed_rank = getattr(layer, "rank")
      rank = [int(r * layer.weight.shape[i]) for i, r in enumerate(normed_rank)] # output channel * normalized rank
      rank = [max(r, 2) for r in rank]

      core, [last, first] = partial_tucker(
          layer.weight.data,
          modes=[0, 1],
          n_iter_max=2000000,
          rank=rank,
          init="svd",
      )

      # A pointwise convolution that reduces the channels from S to R3
      first_layer = nn.Conv2d(
          in_channels=first.shape[0],
          out_channels=first.shape[1],
          kernel_size=1,
          stride=1,
          padding=0,
          dilation=layer.dilation,
          bias=False,
      )

      # A regular 2D convolution layer with R3 input channels
      # and R3 output channels
      core_layer = nn.Conv2d(
          in_channels=core.shape[1],
          out_channels=core.shape[0],
          kernel_size=layer.kernel_size,
          stride=layer.stride,
          padding=layer.padding,
          dilation=layer.dilation,
          bias=False,
      )

      # A pointwise convolution that increases the channels from R4 to T
      last_layer = nn.Conv2d(
          in_channels=last.shape[1],
          out_channels=last.shape[0],
          kernel_size=1,
          stride=1,
          padding=0,
          dilation=layer.dilation,
          bias=True,
      )

      if hasattr(layer, "bias") and layer.bias is not None:
          last_layer.bias.data = layer.bias.data

      first_layer.weight.data = (
          torch.transpose(first, 1, 0).unsqueeze(-1).unsqueeze(-1)
      )
      last_layer.weight.data = last.unsqueeze(-1).unsqueeze(-1)
      core_layer.weight.data = core

      new_layers = [first_layer, core_layer, last_layer]
      return nn.Sequential(*new_layers)

# %% [markdown]
# ### 3-2. Decomposition 수행

# %%
def decompose(module: nn.Module):
  """Iterate model layers and decompose"""
  model_layers = list(module.children())
  if not model_layers:
      return None
  for i in range(len(model_layers)):
      if type(model_layers[i]) == nn.Sequential:
          decomposed_module = decompose(model_layers[i])
          if decomposed_module:
              model_layers[i] = decomposed_module
      if type(model_layers[i]) == nn.Conv2d:
          model_layers[i] = tucker_decomposition_conv_layer(model_layers[i])
  return nn.Sequential(*model_layers)

# %%
test_model.features = decompose(test_model.features)
test_model = test_model.to(DEVICE)

# %%
params_nums = count_model_params(test_model)
print(params_nums)
# Out:
# 4020358

# %% [markdown]
# ### Decomposed 모델 MACs 확인

# %%
macs, params = get_macs(test_model)
print(f'decomposed_model: {macs}')
# Out:
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleReLU ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleMaxPool2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleReLU ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleMaxPool2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleReLU ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleReLU ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleMaxPool2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleReLU ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleReLU ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleMaxPool2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleReLU ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleReLU ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleMaxPool2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleAdaptiveAvgPool2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleLinear ptflops can affect your code!
# Warning: module MyModel is treated as a zero-op.
# MyModel(
#   3.387 M, 100.000% Params, 0.06 GMac, 100.000% MACs,
#   (features): Sequential(
#     3.382 M, 99.849% Params, 0.06 GMac, 99.991% MACs,
#     (0): Sequential(
#       0.003 M, 0.080% Params, 0.003 GMac, 4.634% MACs,
#       (0): Conv2d(0.0 M, 0.000% Params, 0.0 GMac, 0.010% MACs, 3, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): Conv2d(0.001 M, 0.017% Params, 0.001 GMac, 0.991% MACs, 2, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): Conv2d(0.002 M, 0.062% Params, 0.002 GMac, 3.633% MACs, 32, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): BatchNorm2d(0.0 M, 0.004% Params, 0.0 GMac, 0.220% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.110% MACs, inplace=True)
#     (3): MaxPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.110% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       0.029 M, 0.850% Params, 0.007 GMac, 12.385% MACs,
#       (0): Conv2d(0.002 M, 0.060% Params, 0.001 GMac, 0.881% MACs, 64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): Conv2d(0.018 M, 0.544% Params, 0.005 GMac, 7.927% MACs, 32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): Conv2d(0.008 M, 0.246% Params, 0.002 GMac, 3.578% MACs, 64, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (5): BatchNorm2d(0.0 M, 0.008% Params, 0.0 GMac, 0.110% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.055% MACs, inplace=True)
#     (7): MaxPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.055% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Sequential(
#       0.115 M, 3.394% Params, 0.007 GMac, 12.358% MACs,
#       (0): Conv2d(0.008 M, 0.242% Params, 0.001 GMac, 0.881% MACs, 128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): Conv2d(0.074 M, 2.177% Params, 0.005 GMac, 7.927% MACs, 64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): Conv2d(0.033 M, 0.975% Params, 0.002 GMac, 3.550% MACs, 128, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (9): BatchNorm2d(0.001 M, 0.015% Params, 0.0 GMac, 0.055% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.028% MACs, inplace=True)
#     (11): Sequential(
#       0.213 M, 6.296% Params, 0.014 GMac, 22.927% MACs,
#       (0): Conv2d(0.033 M, 0.967% Params, 0.002 GMac, 3.523% MACs, 256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): Conv2d(0.147 M, 4.354% Params, 0.009 GMac, 15.853% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): Conv2d(0.033 M, 0.975% Params, 0.002 GMac, 3.550% MACs, 128, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (12): BatchNorm2d(0.001 M, 0.015% Params, 0.0 GMac, 0.055% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.028% MACs, inplace=True)
#     (14): MaxPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.028% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Sequential(
#       0.459 M, 13.560% Params, 0.007 GMac, 12.344% MACs,
#       (0): Conv2d(0.033 M, 0.967% Params, 0.001 GMac, 0.881% MACs, 256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): Conv2d(0.295 M, 8.707% Params, 0.005 GMac, 7.927% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): Conv2d(0.132 M, 3.885% Params, 0.002 GMac, 3.537% MACs, 256, 512, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (16): BatchNorm2d(0.001 M, 0.030% Params, 0.0 GMac, 0.028% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (17): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.014% MACs, inplace=True)
#     (18): Sequential(
#       0.852 M, 25.169% Params, 0.014 GMac, 22.913% MACs,
#       (0): Conv2d(0.131 M, 3.870% Params, 0.002 GMac, 3.523% MACs, 512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): Conv2d(0.59 M, 17.414% Params, 0.009 GMac, 15.853% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): Conv2d(0.132 M, 3.885% Params, 0.002 GMac, 3.537% MACs, 256, 512, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (19): BatchNorm2d(0.001 M, 0.030% Params, 0.0 GMac, 0.028% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (20): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.014% MACs, inplace=True)
#     (21): MaxPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.014% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (22): Sequential(
#       0.852 M, 25.169% Params, 0.003 GMac, 5.728% MACs,
#       (0): Conv2d(0.131 M, 3.870% Params, 0.001 GMac, 0.881% MACs, 512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): Conv2d(0.59 M, 17.414% Params, 0.002 GMac, 3.963% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): Conv2d(0.132 M, 3.885% Params, 0.001 GMac, 0.884% MACs, 256, 512, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (23): BatchNorm2d(0.001 M, 0.030% Params, 0.0 GMac, 0.007% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (24): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.003% MACs, inplace=True)
#     (25): Sequential(
#       0.852 M, 25.169% Params, 0.003 GMac, 5.728% MACs,
#       (0): Conv2d(0.131 M, 3.870% Params, 0.001 GMac, 0.881% MACs, 512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): Conv2d(0.59 M, 17.414% Params, 0.002 GMac, 3.963% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): Conv2d(0.132 M, 3.885% Params, 0.001 GMac, 0.884% MACs, 256, 512, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (26): BatchNorm2d(0.001 M, 0.030% Params, 0.0 GMac, 0.007% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (27): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.003% MACs, inplace=True)
#     (28): MaxPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.003% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.001% MACs, output_size=(1, 1))
#   (fc): Linear(0.005 M, 0.151% Params, 0.0 GMac, 0.009% MACs, in_features=512, out_features=10, bias=True)
# )
# decomposed_model: 0.06 GMac

# %% [markdown]
# ### Fine tune 및 decomposed 모델 Acc 확인

# %%
print('Fine tune decomposed model')
train(test_model, num_epochs = 10)
# Out:
# Fine tune decomposed model
# epoch : 1 loss: 0.360
# Test acc: 81.87%
# epoch : 2 loss: 0.270
# Test acc: 81.75%
# epoch : 3 loss: 0.225
# Test acc: 82.76%
# epoch : 4 loss: 0.194
# Test acc: 81.47%
# epoch : 5 loss: 0.168
# Test acc: 83.38%
# epoch : 6 loss: 0.153
# Test acc: 82.21%
# epoch : 7 loss: 0.141
# Test acc: 82.24%
# epoch : 8 loss: 0.122
# Test acc: 84.49%
# epoch : 9 loss: 0.118
# Test acc: 83.12%
# epoch : 10 loss: 0.108
# Test acc: 83.40%
# Finished Training
