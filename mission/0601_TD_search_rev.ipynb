# %%
# !pip install tensorly
# !pip install ptflops
# Out:
# Requirement already satisfied: tensorly in /opt/conda/lib/python3.8/site-packages (0.7.0)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.8/site-packages (from tensorly) (1.7.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.8/site-packages (from tensorly) (1.19.2)
# Requirement already satisfied: nose in /opt/conda/lib/python3.8/site-packages (from tensorly) (1.3.7)
# Requirement already satisfied: ptflops in /opt/conda/lib/python3.8/site-packages (0.6.6)
# Requirement already satisfied: torch in /opt/conda/lib/python3.8/site-packages (from ptflops) (1.10.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.8/site-packages (from torch->ptflops) (3.7.4.3)

# %%
# helper function for training(fine-tuning)
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import models, datasets, transforms
from ptflops import get_model_complexity_info

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Pytorch transforms composition
transform = transforms.Compose(
    [
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ]
)
# Pytorch Datasets class
train_dataset = datasets.CIFAR10(
    "./data/cifar10", train=True, download=True, transform=transform
)
test_dataset = datasets.CIFAR10(
    "./data/cifar10", train=False, download=True, transform=transform
)
# Pytorch Dataloader class
TRAIN_DATALOADER = DataLoader(
    train_dataset, batch_size=64, shuffle=True, num_workers=2
)
TEST_DATALOADER = DataLoader(
    test_dataset, batch_size=64, shuffle=False, num_workers=2
)

@torch.no_grad()
def test(model):
  model.eval()
  correct, total = 0, 0
  for i, data in enumerate(TEST_DATALOADER):
    inputs, labels = data[0].to(DEVICE), data[1].to(DEVICE)
    outputs = model(inputs)
    _, preds = torch.max(outputs, 1)
    correct += (preds == labels).sum()
    total += labels.shape[0]
  print(f"Test acc: {correct/total*100.0:.2f}%")

def train(model, num_epochs=5):
  criterion = nn.CrossEntropyLoss()
  optimizer = optim.Adam(model.parameters())
  for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for i, data in enumerate(TRAIN_DATALOADER):
      inputs, labels = data[0].to(DEVICE), data[1].to(DEVICE)
      optimizer.zero_grad()
      outputs = model(inputs)
      
      loss = criterion(outputs, labels)
      loss.backward()
      optimizer.step()
      running_loss += loss.item()
    print('epoch : %d loss: %.3f' %(epoch + 1, running_loss / (i+1)))
    test(model)
  print('Finished Training')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## 1. 모델 및 데이터로더 생성, 학습

# %%
# Create model
class MyModel(nn.Module):
    def __init__(self, model_conv, label=10):
        super().__init__()
        self.features = model_conv.features
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(512, label)

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.fc(x)
        return x

def create_model():
  model_conv = models.squeezenet1_0(pretrained=True)
  return MyModel(model_conv)

def get_macs(model):
  model = model.to(DEVICE)
  # calculate macs
  macs, params = get_model_complexity_info(model, tuple([3, 32, 32]), as_strings=True,
                                           print_per_layer_stat=True, verbose=True)
  return macs, params

# %%
# model creation test
test_model = create_model().to(DEVICE)
print(test_model)
# Out:
# MyModel(
#   (features): Sequential(
#     (0): Conv2d(3, 96, kernel_size=(7, 7), stride=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (3): Fire(
#       (squeeze): Conv2d(96, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (4): Fire(
#       (squeeze): Conv2d(128, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (5): Fire(
#       (squeeze): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (6): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (7): Fire(
#       (squeeze): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (8): Fire(
#       (squeeze): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (9): Fire(
#       (squeeze): Conv2d(384, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (10): Fire(
#       (squeeze): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (11): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (12): Fire(
#       (squeeze): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
def count_model_params(
    model: torch.nn.Module,
) -> int:
    """Count model's parameters"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

params_nums = count_model_params(test_model)
print(params_nums)
# Out:
# 740554

# %% [markdown]
# ### Original 모델 MACs 확인

# %%
macs, params = get_macs(test_model)
print(f'original_model: {macs}')
# Out:
# Warning: module Fire is treated as a zero-op.
# Warning: module MyModel is treated as a zero-op.
# MyModel(
#   0.741 M, 100.000% Params, 0.009 GMac, 100.000% MACs,
#   (features): Sequential(
#     0.735 M, 99.307% Params, 0.009 GMac, 99.939% MACs,
#     (0): Conv2d(0.014 M, 1.919% Params, 0.002 GMac, 25.860% MACs, 3, 96, kernel_size=(7, 7), stride=(2, 2))
#     (1): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.175% MACs, inplace=True)
#     (2): MaxPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.175% MACs, kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (3): Fire(
#       0.012 M, 1.610% Params, 0.0 GMac, 4.677% MACs,
#       (squeeze): Conv2d(0.002 M, 0.210% Params, 0.0 GMac, 0.602% MACs, 96, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.006% MACs, inplace=True)
#       (expand1x1): Conv2d(0.001 M, 0.147% Params, 0.0 GMac, 0.422% MACs, 16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.025% MACs, inplace=True)
#       (expand3x3): Conv2d(0.009 M, 1.253% Params, 0.0 GMac, 3.598% MACs, 16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.025% MACs, inplace=True)
#     )
#     (4): Fire(
#       0.012 M, 1.679% Params, 0.0 GMac, 4.876% MACs,
#       (squeeze): Conv2d(0.002 M, 0.279% Params, 0.0 GMac, 0.800% MACs, 128, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.006% MACs, inplace=True)
#       (expand1x1): Conv2d(0.001 M, 0.147% Params, 0.0 GMac, 0.422% MACs, 16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.025% MACs, inplace=True)
#       (expand3x3): Conv2d(0.009 M, 1.253% Params, 0.0 GMac, 3.598% MACs, 16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.025% MACs, inplace=True)
#     )
#     (5): Fire(
#       0.045 M, 6.123% Params, 0.002 GMac, 17.692% MACs,
#       (squeeze): Conv2d(0.004 M, 0.557% Params, 0.0 GMac, 1.600% MACs, 128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.012% MACs, inplace=True)
#       (expand1x1): Conv2d(0.004 M, 0.570% Params, 0.0 GMac, 1.638% MACs, 32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.050% MACs, inplace=True)
#       (expand3x3): Conv2d(0.037 M, 4.995% Params, 0.001 GMac, 14.342% MACs, 32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.050% MACs, inplace=True)
#     )
#     (6): MaxPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.099% MACs, kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (7): Fire(
#       0.049 M, 6.676% Params, 0.0 GMac, 4.820% MACs,
#       (squeeze): Conv2d(0.008 M, 1.111% Params, 0.0 GMac, 0.797% MACs, 256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.003% MACs, inplace=True)
#       (expand1x1): Conv2d(0.004 M, 0.570% Params, 0.0 GMac, 0.409% MACs, 32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.012% MACs, inplace=True)
#       (expand3x3): Conv2d(0.037 M, 4.995% Params, 0.0 GMac, 3.586% MACs, 32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.012% MACs, inplace=True)
#     )
#     (8): Fire(
#       0.105 M, 14.162% Params, 0.001 GMac, 10.208% MACs,
#       (squeeze): Conv2d(0.012 M, 1.666% Params, 0.0 GMac, 1.196% MACs, 256, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.005% MACs, inplace=True)
#       (expand1x1): Conv2d(0.009 M, 1.270% Params, 0.0 GMac, 0.912% MACs, 48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.019% MACs, inplace=True)
#       (expand3x3): Conv2d(0.083 M, 11.226% Params, 0.001 GMac, 8.058% MACs, 48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.019% MACs, inplace=True)
#     )
#     (9): Fire(
#       0.111 M, 14.992% Params, 0.001 GMac, 10.803% MACs,
#       (squeeze): Conv2d(0.018 M, 2.495% Params, 0.0 GMac, 1.791% MACs, 384, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.005% MACs, inplace=True)
#       (expand1x1): Conv2d(0.009 M, 1.270% Params, 0.0 GMac, 0.912% MACs, 48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.019% MACs, inplace=True)
#       (expand3x3): Conv2d(0.083 M, 11.226% Params, 0.001 GMac, 8.058% MACs, 48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.019% MACs, inplace=True)
#     )
#     (10): Fire(
#       0.189 M, 25.520% Params, 0.002 GMac, 18.375% MACs,
#       (squeeze): Conv2d(0.025 M, 3.327% Params, 0.0 GMac, 2.388% MACs, 384, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.006% MACs, inplace=True)
#       (expand1x1): Conv2d(0.017 M, 2.247% Params, 0.0 GMac, 1.613% MACs, 64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.025% MACs, inplace=True)
#       (expand3x3): Conv2d(0.148 M, 19.946% Params, 0.001 GMac, 14.318% MACs, 64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.025% MACs, inplace=True)
#     )
#     (11): MaxPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.050% MACs, kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (12): Fire(
#       0.197 M, 26.627% Params, 0.0 GMac, 2.130% MACs,
#       (squeeze): Conv2d(0.033 M, 4.433% Params, 0.0 GMac, 0.354% MACs, 512, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.001% MACs, inplace=True)
#       (expand1x1): Conv2d(0.017 M, 2.247% Params, 0.0 GMac, 0.179% MACs, 64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.003% MACs, inplace=True)
#       (expand3x3): Conv2d(0.148 M, 19.946% Params, 0.0 GMac, 1.591% MACs, 64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(0.0 M, 0.000% Params, 0.0 GMac, 0.003% MACs, inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.006% MACs, output_size=(1, 1))
#   (fc): Linear(0.005 M, 0.693% Params, 0.0 GMac, 0.055% MACs, in_features=512, out_features=10, bias=True)
# )
# original_model: 0.01 GMac

# %% [markdown]
# ### Fine tune 및 Original 모델 Acc 확인

# %% [markdown]
# ## 2. Conv에 rank parameter 추가(register_buffer)

# %%
for name, param in test_model.named_modules():
    if isinstance(param, nn.Conv2d):
        param.register_buffer('rank', torch.Tensor([0.5, 0.5])) # rank in, out                                               
        print(param)
# Out:
# Conv2d(3, 96, kernel_size=(7, 7), stride=(2, 2))
# Conv2d(96, 16, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# Conv2d(128, 16, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# Conv2d(384, 48, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))

# %% [markdown]
# ## 3. Decomposition 수행

# %% [markdown]
# ### 3-1. Tucker decomposition 함수

# %%
import copy
import tensorly as tl
from tensorly.decomposition import parafac, partial_tucker
from typing import List
# switch to the PyTorch backend
tl.set_backend('pytorch')

def tucker_decomposition_conv_layer(
      layer: nn.Module,
      normed_rank: List[int] = [0.5, 0.5],
  ) -> nn.Module:
      """Gets a conv layer,
      returns a nn.Sequential object with the Tucker decomposition.
      The ranks are estimated with a Python implementation of VBMF
      https://github.com/CasvandenBogaard/VBMF
      """
      if hasattr(layer, "rank"):
          normed_rank = getattr(layer, "rank")

      rank = [int(r * layer.weight.shape[i]) for i, r in enumerate(normed_rank)] # output channel * normalized rank
      rank = [max(r, 2) for r in rank]

      core, [last, first] = partial_tucker(
          layer.weight.data,
          modes=[0, 1],
          n_iter_max=2000000,
          rank=rank,
          init="svd",
      )

      # A pointwise convolution that reduces the channels from S to R3
      first_layer = nn.Conv2d(
          in_channels=first.shape[0],
          out_channels=first.shape[1],
          kernel_size=1,
          stride=1,
          padding=0,
          dilation=layer.dilation,
          bias=False,
      )

      # A regular 2D convolution layer with R3 input channels
      # and R3 output channels
      core_layer = nn.Conv2d(
          in_channels=core.shape[1],
          out_channels=core.shape[0],
          kernel_size=layer.kernel_size,
          stride=layer.stride,
          padding=layer.padding,
          dilation=layer.dilation,
          bias=False,
      )

      # A pointwise convolution that increases the channels from R4 to T
      last_layer = nn.Conv2d(
          in_channels=last.shape[1],
          out_channels=last.shape[0],
          kernel_size=1,
          stride=1,
          padding=0,
          dilation=layer.dilation,
          bias=True,
      )

      if hasattr(layer, "bias") and layer.bias is not None:
          last_layer.bias.data = layer.bias.data

      first_layer.weight.data = (
          torch.transpose(first, 1, 0).unsqueeze(-1).unsqueeze(-1)
      )
      last_layer.weight.data = last.unsqueeze(-1).unsqueeze(-1)
      core_layer.weight.data = core

      new_layers = [first_layer, core_layer, last_layer]
      return nn.Sequential(*new_layers)

# %% [markdown]
# ### 3-2. Decomposition 수행

# %%
def decompose(module: nn.Module):
    """Iterate model layers and decompose"""
    model_layers = list(module.children())
    if not model_layers:
        return None
    for i in range(len(model_layers)):
        
        if type(model_layers[i]) == nn.Conv2d:
            model_layers[i] = tucker_decomposition_conv_layer(model_layers[i])
        else:

            decomposed_module = decompose(model_layers[i])
            if decomposed_module:
                model_layers[i] = decomposed_module
    return nn.Sequential(*model_layers)

# %%
test_model.features = decompose(test_model.features)
test_model1 = test_model.to(DEVICE)
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Sequential(
#       (0): Sequential(
#         (0): Conv2d(3, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): Sequential(
#         (0): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (2): Sequential(
#         (0): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (1): Sequential(
#       (0): Sequential(
#         (0): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): Sequential(
#         (0): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (2): Sequential(
#         (0): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (2): Sequential(
#       (0): Sequential(
#         (0): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): Sequential(
#         (0): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (2): Sequential(
#         (0): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#   )
#   (1): Sequential(
#     (0): Sequential(
#       (0): Sequential(
#         (0): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): Sequential(
#         (0): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (2): Sequential(
#         (0): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (1): Sequential(
#       (0): Sequential(
#         (0): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): Sequential(
#         (0): Conv2d(2, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): Conv2d(2, 6, kernel_size=(7, 7), stride=(2, 2), bias=False)
#         (2): Conv2d(6, 12, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (2): Sequential(
#         (0): Conv2d(12, 6, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): Conv2d(6, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): Conv2d(12, 24, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (2): Sequential(
#       (0): Sequential(
#         (0): Conv2d(24, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): Conv2d(12, 6, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): Conv2d(6, 12, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): Sequential(
#         (0): Conv2d(12, 6, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): Conv2d(6, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): Conv2d(12, 24, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (2): Sequential(
#         (0): Conv2d(24, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): Conv2d(12, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): Conv2d(24, 48, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#   )
#   (2): Sequential(
#     (0): Sequential(
#       (0): Sequential(
#         (0): Conv2d(48, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): Conv2d(24, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): Conv2d(12, 24, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): Sequential(
#         (0): Conv2d(24, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): Conv2d(12, 6, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): Conv2d(6, 12, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (2): Sequential(
#         (0): Conv2d(12, 6, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): Conv2d(6, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): Conv2d(12, 24, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (1): Sequential(
#       (0): Sequential(
#         (0): Conv2d(24, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): Conv2d(12, 6, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): Conv2d(6, 12, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): Sequential(
#         (0): Conv2d(12, 6, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): Conv2d(6, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): Conv2d(12, 24, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (2): Sequential(
#         (0): Conv2d(24, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): Conv2d(12, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): Conv2d(24, 48, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (2): Sequential(
#       (0): Sequential(
#         (0): Conv2d(48, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): Conv2d(24, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): Conv2d(12, 24, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): Sequential(
#         (0): Conv2d(24, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): Conv2d(12, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): Conv2d(24, 48, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (2): Sequential(
#         (0): Conv2d(48, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): Conv2d(24, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): Conv2d(48, 96, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#   )
# )
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-100-bd99c90aacae> in <module>
# ----> 1 test_model.features = decompose(test_model.features)
#       2 test_model1 = test_model.to(DEVICE)
#
# <ipython-input-99-dc72b02bb106> in decompose(module)
#       7         if type(model_layers[i]) == nn.Sequential:
#       8             print(model_layers[i])
# ----> 9             assert False
#      10             for j in model_layers[i]:
#      11                 print(j)
#
# AssertionError:

# %%
params_nums = count_model_params(test_model1)
print(params_nums)
# Out:
# 735760

# %% [markdown]
# ### Decomposed 모델 MACs 확인

# %%
macs, params = get_macs(test_model)
print(f'decomposed_model: {macs}')
# Out:
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleAdaptiveAvgPool2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleAdaptiveAvgPool2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleAdaptiveAvgPool2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleAdaptiveAvgPool2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleAdaptiveAvgPool2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleAdaptiveAvgPool2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleAdaptiveAvgPool2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleAdaptiveAvgPool2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleAdaptiveAvgPool2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleAdaptiveAvgPool2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleAdaptiveAvgPool2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleAdaptiveAvgPool2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleAdaptiveAvgPool2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleAdaptiveAvgPool2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleAdaptiveAvgPool2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleAdaptiveAvgPool2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleConv2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleBatchNorm2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleAdaptiveAvgPool2d ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleLinear ptflops can affect your code!
# Warning: module SiLU is treated as a zero-op.
# Warning: module ConvNormActivation is treated as a zero-op.
# Warning: module Sigmoid is treated as a zero-op.
# Warning: module SqueezeExcitation is treated as a zero-op.
# Warning: module StochasticDepth is treated as a zero-op.
# Warning: module MBConv is treated as a zero-op.
# Warning: module Dropout is treated as a zero-op.
# Warning: module EfficientNet is treated as a zero-op.
# EfficientNet(
#   5.289 M, 100.000% Params, 0.01 GMac, 100.000% MACs,
#   (features): Sequential(
#     4.008 M, 75.778% Params, 0.009 GMac, 87.274% MACs,
#     (0): ConvNormActivation(
#       0.001 M, 0.018% Params, 0.0 GMac, 2.358% MACs,
#       (0): Conv2d(0.001 M, 0.016% Params, 0.0 GMac, 2.195% MACs, 3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(0.0 M, 0.001% Params, 0.0 GMac, 0.163% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#     )
#     (1): Sequential(
#       0.001 M, 0.027% Params, 0.0 GMac, 2.363% MACs,
#       (0): MBConv(
#         0.001 M, 0.027% Params, 0.0 GMac, 2.363% MACs,
#         (block): Sequential(
#           0.001 M, 0.027% Params, 0.0 GMac, 2.363% MACs,
#           (0): ConvNormActivation(
#             0.0 M, 0.007% Params, 0.0 GMac, 0.894% MACs,
#             (0): Conv2d(0.0 M, 0.005% Params, 0.0 GMac, 0.732% MACs, 32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(0.0 M, 0.001% Params, 0.0 GMac, 0.163% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): SqueezeExcitation(
#             0.001 M, 0.010% Params, 0.0 GMac, 0.087% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.081% MACs, output_size=1)
#             (fc1): Conv2d(0.0 M, 0.005% Params, 0.0 GMac, 0.003% MACs, 32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.0 M, 0.005% Params, 0.0 GMac, 0.003% MACs, 8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (2): ConvNormActivation(
#             0.001 M, 0.010% Params, 0.0 GMac, 1.382% MACs,
#             (0): Conv2d(0.001 M, 0.010% Params, 0.0 GMac, 1.301% MACs, 32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.001% Params, 0.0 GMac, 0.081% MACs, 16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#     )
#     (2): Sequential(
#       0.017 M, 0.316% Params, 0.001 GMac, 12.345% MACs,
#       (0): MBConv(
#         0.006 M, 0.114% Params, 0.001 GMac, 6.625% MACs,
#         (block): Sequential(
#           0.006 M, 0.114% Params, 0.001 GMac, 6.625% MACs,
#           (0): ConvNormActivation(
#             0.002 M, 0.033% Params, 0.0 GMac, 4.390% MACs,
#             (0): Conv2d(0.002 M, 0.029% Params, 0.0 GMac, 3.903% MACs, 16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.004% Params, 0.0 GMac, 0.488% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): ConvNormActivation(
#             0.001 M, 0.020% Params, 0.0 GMac, 0.671% MACs,
#             (0): Conv2d(0.001 M, 0.016% Params, 0.0 GMac, 0.549% MACs, 96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (1): BatchNorm2d(0.0 M, 0.004% Params, 0.0 GMac, 0.122% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             0.001 M, 0.016% Params, 0.0 GMac, 0.070% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.061% MACs, output_size=1)
#             (fc1): Conv2d(0.0 M, 0.007% Params, 0.0 GMac, 0.004% MACs, 96, 4, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.0 M, 0.009% Params, 0.0 GMac, 0.005% MACs, 4, 96, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (3): ConvNormActivation(
#             0.002 M, 0.044% Params, 0.0 GMac, 1.494% MACs,
#             (0): Conv2d(0.002 M, 0.044% Params, 0.0 GMac, 1.463% MACs, 96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.001% Params, 0.0 GMac, 0.030% MACs, 24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0125, mode=row)
#       )
#       (1): MBConv(
#         0.011 M, 0.203% Params, 0.001 GMac, 5.720% MACs,
#         (block): Sequential(
#           0.011 M, 0.203% Params, 0.001 GMac, 5.720% MACs,
#           (0): ConvNormActivation(
#             0.004 M, 0.071% Params, 0.0 GMac, 2.378% MACs,
#             (0): Conv2d(0.003 M, 0.065% Params, 0.0 GMac, 2.195% MACs, 24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.005% Params, 0.0 GMac, 0.183% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): ConvNormActivation(
#             0.002 M, 0.030% Params, 0.0 GMac, 1.006% MACs,
#             (0): Conv2d(0.001 M, 0.025% Params, 0.0 GMac, 0.823% MACs, 144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(0.0 M, 0.005% Params, 0.0 GMac, 0.183% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             0.002 M, 0.036% Params, 0.0 GMac, 0.110% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.091% MACs, output_size=1)
#             (fc1): Conv2d(0.001 M, 0.016% Params, 0.0 GMac, 0.009% MACs, 144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.001 M, 0.019% Params, 0.0 GMac, 0.010% MACs, 6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (3): ConvNormActivation(
#             0.004 M, 0.066% Params, 0.0 GMac, 2.226% MACs,
#             (0): Conv2d(0.003 M, 0.065% Params, 0.0 GMac, 2.195% MACs, 144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.001% Params, 0.0 GMac, 0.030% MACs, 24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.025, mode=row)
#       )
#     )
#     (3): Sequential(
#       0.047 M, 0.882% Params, 0.001 GMac, 8.219% MACs,
#       (0): MBConv(
#         0.015 M, 0.290% Params, 0.0 GMac, 3.964% MACs,
#         (block): Sequential(
#           0.015 M, 0.290% Params, 0.0 GMac, 3.964% MACs,
#           (0): ConvNormActivation(
#             0.004 M, 0.071% Params, 0.0 GMac, 2.378% MACs,
#             (0): Conv2d(0.003 M, 0.065% Params, 0.0 GMac, 2.195% MACs, 24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.005% Params, 0.0 GMac, 0.183% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): ConvNormActivation(
#             0.004 M, 0.074% Params, 0.0 GMac, 0.617% MACs,
#             (0): Conv2d(0.004 M, 0.068% Params, 0.0 GMac, 0.572% MACs, 144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#             (1): BatchNorm2d(0.0 M, 0.005% Params, 0.0 GMac, 0.046% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             0.002 M, 0.036% Params, 0.0 GMac, 0.042% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.023% MACs, output_size=1)
#             (fc1): Conv2d(0.001 M, 0.016% Params, 0.0 GMac, 0.009% MACs, 144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.001 M, 0.019% Params, 0.0 GMac, 0.010% MACs, 6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (3): ConvNormActivation(
#             0.006 M, 0.110% Params, 0.0 GMac, 0.927% MACs,
#             (0): Conv2d(0.006 M, 0.109% Params, 0.0 GMac, 0.915% MACs, 144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.002% Params, 0.0 GMac, 0.013% MACs, 40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.037500000000000006, mode=row)
#       )
#       (1): MBConv(
#         0.031 M, 0.592% Params, 0.0 GMac, 4.255% MACs,
#         (block): Sequential(
#           0.031 M, 0.592% Params, 0.0 GMac, 4.255% MACs,
#           (0): ConvNormActivation(
#             0.01 M, 0.191% Params, 0.0 GMac, 1.601% MACs,
#             (0): Conv2d(0.01 M, 0.182% Params, 0.0 GMac, 1.524% MACs, 40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.009% Params, 0.0 GMac, 0.076% MACs, 240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): ConvNormActivation(
#             0.006 M, 0.123% Params, 0.0 GMac, 1.029% MACs,
#             (0): Conv2d(0.006 M, 0.113% Params, 0.0 GMac, 0.953% MACs, 240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#             (1): BatchNorm2d(0.0 M, 0.009% Params, 0.0 GMac, 0.076% MACs, 240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             0.005 M, 0.095% Params, 0.0 GMac, 0.088% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.038% MACs, output_size=1)
#             (fc1): Conv2d(0.002 M, 0.046% Params, 0.0 GMac, 0.024% MACs, 240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.003 M, 0.050% Params, 0.0 GMac, 0.026% MACs, 10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (3): ConvNormActivation(
#             0.01 M, 0.183% Params, 0.0 GMac, 1.537% MACs,
#             (0): Conv2d(0.01 M, 0.182% Params, 0.0 GMac, 1.524% MACs, 240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.002% Params, 0.0 GMac, 0.013% MACs, 40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05, mode=row)
#       )
#     )
#     (4): Sequential(
#       0.243 M, 4.594% Params, 0.001 GMac, 9.569% MACs,
#       (0): MBConv(
#         0.037 M, 0.702% Params, 0.0 GMac, 2.534% MACs,
#         (block): Sequential(
#           0.037 M, 0.702% Params, 0.0 GMac, 2.534% MACs,
#           (0): ConvNormActivation(
#             0.01 M, 0.191% Params, 0.0 GMac, 1.601% MACs,
#             (0): Conv2d(0.01 M, 0.182% Params, 0.0 GMac, 1.524% MACs, 40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.009% Params, 0.0 GMac, 0.076% MACs, 240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): ConvNormActivation(
#             0.003 M, 0.050% Params, 0.0 GMac, 0.105% MACs,
#             (0): Conv2d(0.002 M, 0.041% Params, 0.0 GMac, 0.086% MACs, 240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#             (1): BatchNorm2d(0.0 M, 0.009% Params, 0.0 GMac, 0.019% MACs, 240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             0.005 M, 0.095% Params, 0.0 GMac, 0.060% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.010% MACs, output_size=1)
#             (fc1): Conv2d(0.002 M, 0.046% Params, 0.0 GMac, 0.024% MACs, 240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.003 M, 0.050% Params, 0.0 GMac, 0.026% MACs, 10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (3): ConvNormActivation(
#             0.019 M, 0.366% Params, 0.0 GMac, 0.769% MACs,
#             (0): Conv2d(0.019 M, 0.363% Params, 0.0 GMac, 0.762% MACs, 240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.003% Params, 0.0 GMac, 0.006% MACs, 80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0625, mode=row)
#       )
#       (1): MBConv(
#         0.103 M, 1.946% Params, 0.0 GMac, 3.518% MACs,
#         (block): Sequential(
#           0.103 M, 1.946% Params, 0.0 GMac, 3.518% MACs,
#           (0): ConvNormActivation(
#             0.039 M, 0.744% Params, 0.0 GMac, 1.563% MACs,
#             (0): Conv2d(0.038 M, 0.726% Params, 0.0 GMac, 1.524% MACs, 80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.001 M, 0.018% Params, 0.0 GMac, 0.038% MACs, 480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): ConvNormActivation(
#             0.005 M, 0.100% Params, 0.0 GMac, 0.210% MACs,
#             (0): Conv2d(0.004 M, 0.082% Params, 0.0 GMac, 0.172% MACs, 480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(0.001 M, 0.018% Params, 0.0 GMac, 0.038% MACs, 480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             0.02 M, 0.373% Params, 0.0 GMac, 0.215% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.019% MACs, output_size=1)
#             (fc1): Conv2d(0.01 M, 0.182% Params, 0.0 GMac, 0.095% MACs, 480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.01 M, 0.191% Params, 0.0 GMac, 0.100% MACs, 20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (3): ConvNormActivation(
#             0.039 M, 0.729% Params, 0.0 GMac, 1.531% MACs,
#             (0): Conv2d(0.038 M, 0.726% Params, 0.0 GMac, 1.524% MACs, 480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.003% Params, 0.0 GMac, 0.006% MACs, 80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.07500000000000001, mode=row)
#       )
#       (2): MBConv(
#         0.103 M, 1.946% Params, 0.0 GMac, 3.518% MACs,
#         (block): Sequential(
#           0.103 M, 1.946% Params, 0.0 GMac, 3.518% MACs,
#           (0): ConvNormActivation(
#             0.039 M, 0.744% Params, 0.0 GMac, 1.563% MACs,
#             (0): Conv2d(0.038 M, 0.726% Params, 0.0 GMac, 1.524% MACs, 80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.001 M, 0.018% Params, 0.0 GMac, 0.038% MACs, 480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): ConvNormActivation(
#             0.005 M, 0.100% Params, 0.0 GMac, 0.210% MACs,
#             (0): Conv2d(0.004 M, 0.082% Params, 0.0 GMac, 0.172% MACs, 480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(0.001 M, 0.018% Params, 0.0 GMac, 0.038% MACs, 480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             0.02 M, 0.373% Params, 0.0 GMac, 0.215% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.019% MACs, output_size=1)
#             (fc1): Conv2d(0.01 M, 0.182% Params, 0.0 GMac, 0.095% MACs, 480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.01 M, 0.191% Params, 0.0 GMac, 0.100% MACs, 20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (3): ConvNormActivation(
#             0.039 M, 0.729% Params, 0.0 GMac, 1.531% MACs,
#             (0): Conv2d(0.038 M, 0.726% Params, 0.0 GMac, 1.524% MACs, 480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.003% Params, 0.0 GMac, 0.006% MACs, 80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08750000000000001, mode=row)
#       )
#     )
#     (5): Sequential(
#       0.543 M, 10.270% Params, 0.002 GMac, 18.766% MACs,
#       (0): MBConv(
#         0.126 M, 2.383% Params, 0.0 GMac, 4.435% MACs,
#         (block): Sequential(
#           0.126 M, 2.383% Params, 0.0 GMac, 4.435% MACs,
#           (0): ConvNormActivation(
#             0.039 M, 0.744% Params, 0.0 GMac, 1.563% MACs,
#             (0): Conv2d(0.038 M, 0.726% Params, 0.0 GMac, 1.524% MACs, 80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.001 M, 0.018% Params, 0.0 GMac, 0.038% MACs, 480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): ConvNormActivation(
#             0.013 M, 0.245% Params, 0.0 GMac, 0.515% MACs,
#             (0): Conv2d(0.012 M, 0.227% Params, 0.0 GMac, 0.476% MACs, 480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#             (1): BatchNorm2d(0.001 M, 0.018% Params, 0.0 GMac, 0.038% MACs, 480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             0.02 M, 0.373% Params, 0.0 GMac, 0.215% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.019% MACs, output_size=1)
#             (fc1): Conv2d(0.01 M, 0.182% Params, 0.0 GMac, 0.095% MACs, 480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.01 M, 0.191% Params, 0.0 GMac, 0.100% MACs, 20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (3): ConvNormActivation(
#             0.054 M, 1.021% Params, 0.0 GMac, 2.143% MACs,
#             (0): Conv2d(0.054 M, 1.017% Params, 0.0 GMac, 2.134% MACs, 480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.004% Params, 0.0 GMac, 0.009% MACs, 112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#       )
#       (1): MBConv(
#         0.209 M, 3.944% Params, 0.001 GMac, 7.166% MACs,
#         (block): Sequential(
#           0.209 M, 3.944% Params, 0.001 GMac, 7.166% MACs,
#           (0): ConvNormActivation(
#             0.077 M, 1.449% Params, 0.0 GMac, 3.041% MACs,
#             (0): Conv2d(0.075 M, 1.423% Params, 0.0 GMac, 2.988% MACs, 112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.001 M, 0.025% Params, 0.0 GMac, 0.053% MACs, 672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): ConvNormActivation(
#             0.018 M, 0.343% Params, 0.0 GMac, 0.720% MACs,
#             (0): Conv2d(0.017 M, 0.318% Params, 0.0 GMac, 0.667% MACs, 672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(0.001 M, 0.025% Params, 0.0 GMac, 0.053% MACs, 672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             0.038 M, 0.725% Params, 0.0 GMac, 0.407% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.027% MACs, output_size=1)
#             (fc1): Conv2d(0.019 M, 0.356% Params, 0.0 GMac, 0.187% MACs, 672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.019 M, 0.368% Params, 0.0 GMac, 0.193% MACs, 28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (3): ConvNormActivation(
#             0.075 M, 1.427% Params, 0.0 GMac, 2.997% MACs,
#             (0): Conv2d(0.075 M, 1.423% Params, 0.0 GMac, 2.988% MACs, 672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.004% Params, 0.0 GMac, 0.009% MACs, 112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1125, mode=row)
#       )
#       (2): MBConv(
#         0.209 M, 3.944% Params, 0.001 GMac, 7.166% MACs,
#         (block): Sequential(
#           0.209 M, 3.944% Params, 0.001 GMac, 7.166% MACs,
#           (0): ConvNormActivation(
#             0.077 M, 1.449% Params, 0.0 GMac, 3.041% MACs,
#             (0): Conv2d(0.075 M, 1.423% Params, 0.0 GMac, 2.988% MACs, 112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.001 M, 0.025% Params, 0.0 GMac, 0.053% MACs, 672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): ConvNormActivation(
#             0.018 M, 0.343% Params, 0.0 GMac, 0.720% MACs,
#             (0): Conv2d(0.017 M, 0.318% Params, 0.0 GMac, 0.667% MACs, 672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(0.001 M, 0.025% Params, 0.0 GMac, 0.053% MACs, 672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             0.038 M, 0.725% Params, 0.0 GMac, 0.407% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.027% MACs, output_size=1)
#             (fc1): Conv2d(0.019 M, 0.356% Params, 0.0 GMac, 0.187% MACs, 672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.019 M, 0.368% Params, 0.0 GMac, 0.193% MACs, 28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (3): ConvNormActivation(
#             0.075 M, 1.427% Params, 0.0 GMac, 2.997% MACs,
#             (0): Conv2d(0.075 M, 1.423% Params, 0.0 GMac, 2.988% MACs, 672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.004% Params, 0.0 GMac, 0.009% MACs, 112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.125, mode=row)
#       )
#     )
#     (6): Sequential(
#       2.026 M, 38.316% Params, 0.002 GMac, 22.433% MACs,
#       (0): MBConv(
#         0.262 M, 4.963% Params, 0.0 GMac, 4.893% MACs,
#         (block): Sequential(
#           0.262 M, 4.963% Params, 0.0 GMac, 4.893% MACs,
#           (0): ConvNormActivation(
#             0.077 M, 1.449% Params, 0.0 GMac, 3.041% MACs,
#             (0): Conv2d(0.075 M, 1.423% Params, 0.0 GMac, 2.988% MACs, 112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.001 M, 0.025% Params, 0.0 GMac, 0.053% MACs, 672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): ConvNormActivation(
#             0.018 M, 0.343% Params, 0.0 GMac, 0.180% MACs,
#             (0): Conv2d(0.017 M, 0.318% Params, 0.0 GMac, 0.167% MACs, 672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(0.001 M, 0.025% Params, 0.0 GMac, 0.013% MACs, 672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             0.038 M, 0.725% Params, 0.0 GMac, 0.387% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.007% MACs, output_size=1)
#             (fc1): Conv2d(0.019 M, 0.356% Params, 0.0 GMac, 0.187% MACs, 672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.019 M, 0.368% Params, 0.0 GMac, 0.193% MACs, 28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (3): ConvNormActivation(
#             0.129 M, 2.447% Params, 0.0 GMac, 1.284% MACs,
#             (0): Conv2d(0.129 M, 2.440% Params, 0.0 GMac, 1.281% MACs, 672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.007% Params, 0.0 GMac, 0.004% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1375, mode=row)
#       )
#       (1): MBConv(
#         0.588 M, 11.117% Params, 0.001 GMac, 5.847% MACs,
#         (block): Sequential(
#           0.588 M, 11.117% Params, 0.001 GMac, 5.847% MACs,
#           (0): ConvNormActivation(
#             0.223 M, 4.226% Params, 0.0 GMac, 2.218% MACs,
#             (0): Conv2d(0.221 M, 4.182% Params, 0.0 GMac, 2.195% MACs, 192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.002 M, 0.044% Params, 0.0 GMac, 0.023% MACs, 1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): ConvNormActivation(
#             0.031 M, 0.588% Params, 0.0 GMac, 0.309% MACs,
#             (0): Conv2d(0.029 M, 0.545% Params, 0.0 GMac, 0.286% MACs, 1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(0.002 M, 0.044% Params, 0.0 GMac, 0.023% MACs, 1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             0.112 M, 2.114% Params, 0.0 GMac, 1.121% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.011% MACs, output_size=1)
#             (fc1): Conv2d(0.055 M, 1.046% Params, 0.0 GMac, 0.549% MACs, 1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.056 M, 1.067% Params, 0.0 GMac, 0.560% MACs, 48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (3): ConvNormActivation(
#             0.222 M, 4.190% Params, 0.0 GMac, 2.199% MACs,
#             (0): Conv2d(0.221 M, 4.182% Params, 0.0 GMac, 2.195% MACs, 1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.007% Params, 0.0 GMac, 0.004% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.15000000000000002, mode=row)
#       )
#       (2): MBConv(
#         0.588 M, 11.117% Params, 0.001 GMac, 5.847% MACs,
#         (block): Sequential(
#           0.588 M, 11.117% Params, 0.001 GMac, 5.847% MACs,
#           (0): ConvNormActivation(
#             0.223 M, 4.226% Params, 0.0 GMac, 2.218% MACs,
#             (0): Conv2d(0.221 M, 4.182% Params, 0.0 GMac, 2.195% MACs, 192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.002 M, 0.044% Params, 0.0 GMac, 0.023% MACs, 1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): ConvNormActivation(
#             0.031 M, 0.588% Params, 0.0 GMac, 0.309% MACs,
#             (0): Conv2d(0.029 M, 0.545% Params, 0.0 GMac, 0.286% MACs, 1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(0.002 M, 0.044% Params, 0.0 GMac, 0.023% MACs, 1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             0.112 M, 2.114% Params, 0.0 GMac, 1.121% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.011% MACs, output_size=1)
#             (fc1): Conv2d(0.055 M, 1.046% Params, 0.0 GMac, 0.549% MACs, 1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.056 M, 1.067% Params, 0.0 GMac, 0.560% MACs, 48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (3): ConvNormActivation(
#             0.222 M, 4.190% Params, 0.0 GMac, 2.199% MACs,
#             (0): Conv2d(0.221 M, 4.182% Params, 0.0 GMac, 2.195% MACs, 1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.007% Params, 0.0 GMac, 0.004% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1625, mode=row)
#       )
#       (3): MBConv(
#         0.588 M, 11.117% Params, 0.001 GMac, 5.847% MACs,
#         (block): Sequential(
#           0.588 M, 11.117% Params, 0.001 GMac, 5.847% MACs,
#           (0): ConvNormActivation(
#             0.223 M, 4.226% Params, 0.0 GMac, 2.218% MACs,
#             (0): Conv2d(0.221 M, 4.182% Params, 0.0 GMac, 2.195% MACs, 192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.002 M, 0.044% Params, 0.0 GMac, 0.023% MACs, 1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): ConvNormActivation(
#             0.031 M, 0.588% Params, 0.0 GMac, 0.309% MACs,
#             (0): Conv2d(0.029 M, 0.545% Params, 0.0 GMac, 0.286% MACs, 1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(0.002 M, 0.044% Params, 0.0 GMac, 0.023% MACs, 1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             0.112 M, 2.114% Params, 0.0 GMac, 1.121% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.011% MACs, output_size=1)
#             (fc1): Conv2d(0.055 M, 1.046% Params, 0.0 GMac, 0.549% MACs, 1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.056 M, 1.067% Params, 0.0 GMac, 0.560% MACs, 48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (3): ConvNormActivation(
#             0.222 M, 4.190% Params, 0.0 GMac, 2.199% MACs,
#             (0): Conv2d(0.221 M, 4.182% Params, 0.0 GMac, 2.195% MACs, 1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.0 M, 0.007% Params, 0.0 GMac, 0.004% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17500000000000002, mode=row)
#       )
#     )
#     (7): Sequential(
#       0.717 M, 13.562% Params, 0.001 GMac, 7.130% MACs,
#       (0): MBConv(
#         0.717 M, 13.562% Params, 0.001 GMac, 7.130% MACs,
#         (block): Sequential(
#           0.717 M, 13.562% Params, 0.001 GMac, 7.130% MACs,
#           (0): ConvNormActivation(
#             0.223 M, 4.226% Params, 0.0 GMac, 2.218% MACs,
#             (0): Conv2d(0.221 M, 4.182% Params, 0.0 GMac, 2.195% MACs, 192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.002 M, 0.044% Params, 0.0 GMac, 0.023% MACs, 1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (1): ConvNormActivation(
#             0.013 M, 0.240% Params, 0.0 GMac, 0.126% MACs,
#             (0): Conv2d(0.01 M, 0.196% Params, 0.0 GMac, 0.103% MACs, 1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#             (1): BatchNorm2d(0.002 M, 0.044% Params, 0.0 GMac, 0.023% MACs, 1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             0.112 M, 2.114% Params, 0.0 GMac, 1.121% MACs,
#             (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.011% MACs, output_size=1)
#             (fc1): Conv2d(0.055 M, 1.046% Params, 0.0 GMac, 0.549% MACs, 1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(0.056 M, 1.067% Params, 0.0 GMac, 0.560% MACs, 48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, )
#           )
#           (3): ConvNormActivation(
#             0.369 M, 6.983% Params, 0.0 GMac, 3.665% MACs,
#             (0): Conv2d(0.369 M, 6.971% Params, 0.0 GMac, 3.659% MACs, 1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(0.001 M, 0.012% Params, 0.0 GMac, 0.006% MACs, 320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1875, mode=row)
#       )
#     )
#     (8): ConvNormActivation(
#       0.412 M, 7.793% Params, 0.0 GMac, 4.091% MACs,
#       (0): Conv2d(0.41 M, 7.745% Params, 0.0 GMac, 4.065% MACs, 320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(0.003 M, 0.048% Params, 0.0 GMac, 0.025% MACs, 1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(0.0 M, 0.000% Params, 0.0 GMac, 0.013% MACs, output_size=1)
#   (classifier): Sequential(
#     1.281 M, 24.222% Params, 0.001 GMac, 12.714% MACs,
#     (0): Dropout(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, p=0.2, inplace=True)
#     (1): Linear(1.281 M, 24.222% Params, 0.001 GMac, 12.714% MACs, in_features=1280, out_features=1000, bias=True)
#   )
# )
# decomposed_model: 0.01 GMac

# %% [markdown]
# ### Fine tune 및 decomposed 모델 Acc 확인

# %%
print('Fine tune decomposed model')
train(test_model, num_epochs = 10)
# Out:
# Fine tune decomposed model
# epoch : 1 loss: 0.360
# Test acc: 81.87%
# epoch : 2 loss: 0.270
# Test acc: 81.75%
# epoch : 3 loss: 0.225
# Test acc: 82.76%
# epoch : 4 loss: 0.194
# Test acc: 81.47%
# epoch : 5 loss: 0.168
# Test acc: 83.38%
# epoch : 6 loss: 0.153
# Test acc: 82.21%
# epoch : 7 loss: 0.141
# Test acc: 82.24%
# epoch : 8 loss: 0.122
# Test acc: 84.49%
# epoch : 9 loss: 0.118
# Test acc: 83.12%
# epoch : 10 loss: 0.108
# Test acc: 83.40%
# Finished Training
